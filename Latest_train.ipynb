# %% [markdown]
# # Mount google drive [ML_Khasi to English]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/MT_Context_Src
# Out:
# /content/drive/MyDrive/MT_Context_Src

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 57.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 28.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 122.3 MB/s eta 0:00:00
# ...

# %%
# !pip install dill
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 3.3 MB/s eta 0:00:00
# ...

# %%
  # !python train.py
# Out:
# 2023-05-11 19:30:11.086003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...
# loading presaved train and val datasets...
# training model...
# Learning rate:0.0001 Batch_size:128 Shuffle:False
# Learning rate: 0.000100
#    18m: epoch 69 [                    ]  0%  train loss = 0.006  validation loss = 0.008  Validation_Accuracy= 0.91 lr=0.000100
#    18m: epoch 69 [                    ]  0%  train loss = 0.006  validation loss = 0.006  Validation_Accuracy= 0.92 lr=0.000100
#    18m: epoch 69 [                    ]  0%  train loss = 0.006  validation loss = 0.006  Validation_Accuracy= 0.92 lr=0.000100
#    18m: epoch 69 [                    ]  0%  train loss = 0.006  validation loss = 0.006  Validation_Accuracy= 0.92 lr=0.000100
#    19m: epoch 69 [                    ]  0%  train loss = 0.006  validation loss = 0.006  Validation_Accuracy= 0.92 lr=0.000100
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python translate.py
# Out:
# ...
# Enter a sentence to translate (type 'f' to load from file, or 'q' to quit):
# f
# Enter the File name in .txt format:
# Note File should be located in: data/ Directory:
# Test_kha.txt
#   0% 0/11473 [00:00<?, ?it/s]2023-05-12 03:57:57.148891: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 100% 11473/11473 [57:19<00:00,  3.34it/s]
# Enter a sentence to translate (type 'f' to load from file, or 'q' to quit):

# %%
# !python translate_hybrid.py
# Out:
# ...
# Enter a sentence to translate (type 'f' to load from file, or 'q' to quit):
# f
# Enter the File name in .txt format:
# Note File should be located in: data/ Directory:
# Test_kha.txt
#   0% 0/11473 [00:00<?, ?it/s]2023-05-15 06:04:18.803174: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
#  32% 3664/11473 [17:33<32:58,  3.95it/s]
