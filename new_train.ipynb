# %%
# !python train.py
# Out:
# loading presaved train and val datasets...
# training model...
# Learning rate:0.0001 Batch_size:64 Shuffle:False
# Learning rate: 0.000300
#    23m: epoch 9 [                    ]  0%  train loss = 0.043  validation loss = 0.043  Validation_Accuracy= 0.29 lr=0.000298
#    23m: epoch 9 [                    ]  0%  train loss = 0.043  validation loss = 0.043  Validation_Accuracy= 0.29 lr=0.000298
#    23m: epoch 9 [                    ]  0%  train loss = 0.043  validation loss = 0.043  Validation_Accuracy= 0.29 lr=0.000298
#    24m: epoch 9 [                    ]  0%  train loss = 0.043  validation loss = 0.043  Validation_Accuracy= 0.29 lr=0.000298
#    24m: epoch 9 [                    ]  0%  train loss = 0.043  validation loss = 0.042  Validation_Accuracy= 0.29 lr=0.000298
#    24m: epoch 9 [                    ]  0%  train loss = 0.043  validation loss = 0.042  Validation_Accuracy= 0.29 lr=0.000298
# ...
